# %% [markdown]
# Задача No57.
# - Прочесть с помощью pandas файл california_housing_test.csv, который находится в папке sample_data
# - Посмотреть сколько в нем строк и столбцов
# - Определить какой тип данных имеют столбцы

# %%
import pandas as pd

# %%
df = pd.read_csv("sample_data/california_housing_test.csv")
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
df.sample(20)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 739     -121.07     39.20                45.0        204.0            62.0
# 2871    -121.09     38.97                13.0       1467.0           221.0
# 2658    -121.89     37.35                48.0       1562.0           439.0
# 135     -122.34     37.56                39.0       3562.0           391.0
# 576     -118.29     33.84                33.0        896.0           208.0
# 487     -118.19     33.82                11.0        872.0           203.0
# 1774    -118.16     33.96                24.0       1635.0           507.0
# 1984    -121.98     38.39                 3.0       9488.0          1417.0
# 242     -123.21     39.14                15.0       2235.0           545.0
# 986     -118.15     34.10                39.0       3856.0           867.0
# 1574    -117.05     32.71                25.0       3292.0           608.0
# 2859    -118.22     33.99                 6.0       1499.0           437.0
# 2952    -118.02     33.91                34.0       2518.0           429.0
# 916     -117.99     34.08                35.0       1032.0           207.0
# 1502    -121.35     38.68                20.0       7085.0          1222.0
# 1854    -121.80     37.32                23.0       1829.0           346.0
# 2672    -118.23     34.15                19.0       2294.0           716.0
# 261     -118.26     33.88                36.0       1212.0           222.0
# 1773    -121.53     38.60                25.0       5154.0          1105.0
# 2900    -121.45     38.56                51.0       1250.0           235.0
#
#       population  households  median_income  median_house_value
# 739        133.0        51.0         1.0000             90600.0
# 2871       688.0       231.0         5.2536            191900.0
# 2658      1469.0       424.0         2.5673            177500.0
# 135       1139.0       391.0        12.6417            500001.0
# 576        843.0       200.0         3.5000            183000.0
# 487        422.0       221.0         4.6364            156300.0
# 1774      2480.0       481.0         2.4432            187500.0
# 1984      4095.0      1335.0         5.1781            191900.0
# 242       1376.0       516.0         1.9032            100000.0
# 986       1847.0       830.0         3.4559            364900.0
# 1574      2266.0       592.0         3.2986            119200.0
# 2859      1754.0       447.0         4.3164            143200.0
# 2952      1309.0       421.0         4.7861            210700.0
# 916        954.0       191.0         2.8906            134800.0
# 1502      3455.0      1229.0         4.3118            120000.0
# 1854      1277.0       324.0         4.8092            217400.0
# 2672      1686.0       680.0         3.0288            258300.0
# 261        775.0       224.0         5.5591            136500.0
# 1773      3196.0      1073.0         2.7566             80200.0
# 2900       452.0       232.0         2.6250            121200.0

# %%
df.shape
# Out:
# (3000, 9)

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %%
df.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# 25%        291.000000    780.000000   273.00000       2.544000
# 50%        437.000000   1155.000000   409.50000       3.487150
# 75%        636.000000   1742.750000   597.25000       4.656475
# max       5419.000000  11935.000000  4930.00000      15.000100
#
#        median_house_value
# count          3000.00000
# mean         205846.27500
# std          113119.68747
# min           22500.00000
# 25%          121200.00000
# 50%          177650.00000
# 75%          263975.00000
# max          500001.00000

# %% [markdown]
# Задача No59.
# - Проверить есть ли в файле пустые значения
# - Показать median_house_value где median_income < 2
# - Показать данные в первых 2 столбцах
# - Выбрать данные где housing_median_age < 20 и median_house_value > 70000

# %%
df.isna().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
df[df["median_income"] < 2]["median_house_value"]
# Out:
# 5        67000.0
# 6        67000.0
# 16      181300.0
# 28      350000.0
# 43       79300.0
#           ...
# 2943     57200.0
# 2964     91300.0
# 2985    109400.0
# 2986     85400.0
# 2995    225000.0
# Name: median_house_value, Length: 360, dtype: float64

# %%
df.loc[df["median_income"] < 2,"median_house_value"]
# Out:
# 5        67000.0
# 6        67000.0
# 16      181300.0
# 28      350000.0
# 43       79300.0
#           ...
# 2943     57200.0
# 2964     91300.0
# 2985    109400.0
# 2986     85400.0
# 2995    225000.0
# Name: median_house_value, Length: 360, dtype: float64

# %%
df[['longitude', 'latitude']]
# Out:
#       longitude  latitude
# 0       -122.05     37.37
# 1       -118.30     34.26
# 2       -117.81     33.78
# 3       -118.36     33.82
# 4       -119.67     36.33
# ...         ...       ...
# 2995    -119.86     34.42
# 2996    -118.14     34.06
# 2997    -119.70     36.30
# 2998    -117.12     34.10
# 2999    -119.63     34.42
#
# [3000 rows x 2 columns]

# %%
df.iloc[:,[0,1]]
# Out:
#       longitude  latitude
# 0       -122.05     37.37
# 1       -118.30     34.26
# 2       -117.81     33.78
# 3       -118.36     33.82
# 4       -119.67     36.33
# ...         ...       ...
# 2995    -119.86     34.42
# 2996    -118.14     34.06
# 2997    -119.70     36.30
# 2998    -117.12     34.10
# 2999    -119.63     34.42
#
# [3000 rows x 2 columns]

# %%
df.columns[:2]
# Out:
# Index(['longitude', 'latitude'], dtype='object')

# %%
for col in df.columns[:2]:
  print (df[col])
# Out:
# 0      -122.05
# 1      -118.30
# 2      -117.81
# 3      -118.36
# 4      -119.67
#          ...
# 2995   -119.86
# 2996   -118.14
# 2997   -119.70
# 2998   -117.12
# 2999   -119.63
# Name: longitude, Length: 3000, dtype: float64
# 0       37.37
# 1       34.26
# 2       33.78
# 3       33.82
# 4       36.33
#         ...
# 2995    34.42
# 2996    34.06
# 2997    36.30
# 2998    34.10
# 2999    34.42
# Name: latitude, Length: 3000, dtype: float64

# %%
df[df.columns[:2]]
# Out:
#       longitude  latitude
# 0       -122.05     37.37
# 1       -118.30     34.26
# 2       -117.81     33.78
# 3       -118.36     33.82
# 4       -119.67     36.33
# ...         ...       ...
# 2995    -119.86     34.42
# 2996    -118.14     34.06
# 2997    -119.70     36.30
# 2998    -117.12     34.10
# 2999    -119.63     34.42
#
# [3000 rows x 2 columns]

# %%
df[(df["housing_median_age"] < 20) & (df["median_house_value"] > 70000)]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4       -119.67     36.33                19.0       1241.0           244.0
# 7       -120.65     35.48                19.0       2310.0           471.0
# 8       -122.84     38.40                15.0       3080.0           617.0
# 13      -117.03     32.97                16.0       3936.0           694.0
# 16      -120.81     37.53                15.0        570.0           123.0
# ...         ...       ...                 ...          ...             ...
# 2978    -121.34     38.64                17.0       2761.0           501.0
# 2981    -120.66     35.49                17.0       4422.0           945.0
# 2984    -117.59     33.88                13.0       3239.0           849.0
# 2985    -120.47     34.94                17.0       1368.0           308.0
# 2991    -117.17     34.28                13.0       4867.0           718.0
#
#       population  households  median_income  median_house_value
# 4          850.0       237.0         2.9375             81700.0
# 7         1341.0       441.0         3.2250            166900.0
# 8         1446.0       599.0         3.6696            194400.0
# 13        1935.0       659.0         4.5625            231200.0
# 16         189.0       107.0         1.8750            181300.0
# ...          ...         ...            ...                 ...
# 2978      1128.0       482.0         3.7562            139700.0
# 2981      2307.0       885.0         2.8285            171300.0
# 2984      2751.0       813.0         2.6111            107000.0
# 2985       642.0       303.0         1.8633            109400.0
# 2991       780.0       250.0         7.1997            253800.0
#
# [792 rows x 9 columns]

# %% [markdown]
# Задача No61.
# - Определить какое максимальное и минимальное значение median_house_value
# - Показать максимальное median_house_value, где median_income = 3.1250
# - Узнать какая максимальная population в зоне минимального значения median_house_value

# %%
df['median_house_value'].min(), df['median_house_value'].max()
# Out:
# (22500.0, 500001.0)

# %%
df[df['median_income'] == 3.1250]['median_house_value'].max()
# Out:
# 233300.0

# %%
df[df['median_house_value']== df['median_house_value'].min()]['population'].max()
# Out:
# 1230.0

# %% [markdown]
# Задача 40: Работать с файлом california_housing_train.csv, который находится в папке sample_data. Определить среднюю стоимость дома, где кол-во людей от 0 до 500 (population).

# %%
df = pd.read_csv("sample_data/california_housing_train.csv")
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
df[(df['population'] > 0) & (df["population"] < 500)].median_house_value.mean().round()
# Out:
# 206684.0

# %% [markdown]
# Задача 42: Узнать какая максимальная households в зоне минимального значения population.

# %%
df[df['population'] == df["population"].min()].households.max()
# Out:
# 4.0
