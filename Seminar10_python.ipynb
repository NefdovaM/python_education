# %%
import pandas as pd

# %%
df=pd.read_csv('sample_data/california_housing_test.csv')
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ***Задача №63.***
# 1. Изобразите отношение households к population с
# помощью точечного графика

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=df, x='households', y='population');

# %% [markdown]
# 2. Визуализировать longitude по отношения к
# median_house_value, используя линейный график

# %%
sns.relplot(x='longitude', y='median_house_value', kind='line', data=df);

# %% [markdown]
# 3. Представить гистограмму по housing_median_age

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=df, x='housing_median_age');

# %% [markdown]
# 4. Изобразить гистограмму по median_house_value с
# оттенком housing_median_age

# %%
plt.figure(figsize=(5,10))
sns.displot(data=df, x='median_house_value', hue='housing_median_age');

# %% [markdown]
# ***Задача №65.***
# Написать EDA для датасета про пингвинов

# %%
penguins = sns.load_dataset("penguins")
penguins.sample(10)
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 136     Adelie      Dream            35.6           17.5              191.0
# 272     Gentoo     Biscoe            45.1           14.4              210.0
# 311     Gentoo     Biscoe            52.2           17.1              228.0
# 52      Adelie     Biscoe            35.0           17.9              190.0
# 159  Chinstrap      Dream            51.3           18.2              197.0
# 19      Adelie  Torgersen            46.0           21.5              194.0
# 307     Gentoo     Biscoe            51.3           14.2              218.0
# 269     Gentoo     Biscoe            45.2           15.8              215.0
# 149     Adelie      Dream            37.8           18.1              193.0
# 33      Adelie      Dream            40.9           18.9              184.0
#
#      body_mass_g     sex
# 136       3175.0  Female
# 272       4400.0  Female
# 311       5400.0    Male
# 52        3450.0  Female
# 159       3750.0    Male
# 19        4200.0    Male
# 307       5300.0    Male
# 269       5300.0    Male
# 149       3750.0    Male
# 33        3900.0    Male

# %% [markdown]
# ● Использовать 2-3 точечных графика
#
# ● Применить доп измерение в точечных графиках, используя
# аргументы hue, size, stile

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=penguins, x='bill_length_mm', y='bill_depth_mm', hue='sex', size='body_mass_g' , style='species');

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=penguins, x='bill_length_mm', y='flipper_length_mm', hue='sex', size='body_mass_g' , style='species');

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=penguins, x='bill_length_mm', y='body_mass_g', hue='sex', size='flipper_length_mm' , style='species');

# %% [markdown]
# ● Использовать PairGrid с типом графика на ваш выбор

# %%
g=sns.PairGrid(data=penguins,)
g.map(sns.scatterplot)

# %% [markdown]
# ● Изобразить Heatmap

# %%
corr_penguins = penguins.corr().round(2)
corr_penguins
# Out:
# <ipython-input-12-a29146e1c0b6>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_penguins = penguins.corr().round(2)
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm               1.00          -0.24               0.66
# bill_depth_mm               -0.24           1.00              -0.58
# flipper_length_mm            0.66          -0.58               1.00
# body_mass_g                  0.60          -0.47               0.87
#
#                    body_mass_g
# bill_length_mm            0.60
# bill_depth_mm            -0.47
# flipper_length_mm         0.87
# body_mass_g               1.00

# %%
plt.figure(figsize=(5,5))
sns.heatmap(corr_penguins, annot=True, linewidths=2, cmap='coolwarm');

# %% [markdown]
# ● Использовать 2-3 гистограммы

# %%
plt.figure(figsize=(5,3))
sns.histplot(data=penguins, x='flipper_length_mm');

# %%
plt.figure(figsize=(5,3))
sns.histplot(data=penguins, x='bill_length_mm');

# %%
plt.figure(figsize=(5,3))
sns.histplot(data=penguins, x='body_mass_g');

# %% [markdown]
# ***Задача №67.***
# 1. Создать новый столбец в таблице с
# пингвинами, который будет отвечать за
# показатель длины клюва пингвина.
# high - длинный(от 42)
# middle - средний(от 35 до 42)
# low - маленький(до 35)

# %%
penguins.loc[penguins['bill_length_mm']>=42, 'height_group'] = 'high'
penguins.sample(10)
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 289     Gentoo     Biscoe            50.7           15.0              223.0
# 135     Adelie      Dream            41.1           17.5              190.0
# 260     Gentoo     Biscoe            42.7           13.7              208.0
# 12      Adelie  Torgersen            41.1           17.6              182.0
# 165  Chinstrap      Dream            52.0           18.1              201.0
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 252     Gentoo     Biscoe            45.1           14.5              207.0
# 118     Adelie  Torgersen            35.7           17.0              189.0
# 55      Adelie     Biscoe            41.4           18.6              191.0
# 288     Gentoo     Biscoe            43.5           14.2              220.0
#
#      body_mass_g     sex height_group
# 289       5550.0    Male         high
# 135       3900.0    Male          NaN
# 260       3950.0  Female         high
# 12        3200.0  Female          NaN
# 165       4050.0    Male         high
# 0         3750.0    Male          NaN
# 252       5050.0  Female         high
# 118       3350.0  Female          NaN
# 55        3700.0    Male          NaN
# 288       4700.0  Female         high

# %%
penguins.loc[(penguins['bill_length_mm']>=35) & (penguins['bill_length_mm']<42), 'height_group'] = 'middle'
penguins.sample(10)
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 31      Adelie      Dream            37.2           18.1              178.0
# 16      Adelie  Torgersen            38.7           19.0              195.0
# 216  Chinstrap      Dream            43.5           18.1              202.0
# 180  Chinstrap      Dream            46.4           17.8              191.0
# 33      Adelie      Dream            40.9           18.9              184.0
# 222     Gentoo     Biscoe            48.7           14.1              210.0
# 79      Adelie  Torgersen            42.1           19.1              195.0
# 58      Adelie     Biscoe            36.5           16.6              181.0
# 67      Adelie     Biscoe            41.1           19.1              188.0
# 144     Adelie      Dream            37.3           16.8              192.0
#
#      body_mass_g     sex height_group
# 31        3900.0    Male       middle
# 16        3450.0  Female       middle
# 216       3400.0  Female         high
# 180       3700.0  Female         high
# 33        3900.0    Male       middle
# 222       4450.0  Female         high
# 79        4000.0    Male         high
# 58        2850.0  Female       middle
# 67        4100.0    Male       middle
# 144       3000.0  Female       middle

# %%
penguins.loc[penguins['bill_length_mm']<35, 'height_group'] = 'low'
penguins.sample(50)
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 236     Gentoo     Biscoe            42.0           13.5              210.0
# 308     Gentoo     Biscoe            47.5           14.0              212.0
# 252     Gentoo     Biscoe            45.1           14.5              207.0
# 202  Chinstrap      Dream            48.1           16.4              199.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 185  Chinstrap      Dream            51.0           18.8              203.0
# 261     Gentoo     Biscoe            49.6           16.0              225.0
# 200  Chinstrap      Dream            51.5           18.7              187.0
# 49      Adelie      Dream            42.3           21.2              191.0
# 27      Adelie     Biscoe            40.5           17.9              187.0
# 66      Adelie     Biscoe            35.5           16.2              195.0
# 254     Gentoo     Biscoe            49.1           14.8              220.0
# 31      Adelie      Dream            37.2           18.1              178.0
# 103     Adelie     Biscoe            37.8           20.0              190.0
# 13      Adelie  Torgersen            38.6           21.2              191.0
# 284     Gentoo     Biscoe            45.8           14.2              219.0
# 303     Gentoo     Biscoe            50.0           15.9              224.0
# 273     Gentoo     Biscoe            50.1           15.0              225.0
# 83      Adelie  Torgersen            35.1           19.4              193.0
# 336     Gentoo     Biscoe            44.5           15.7              217.0
# 248     Gentoo     Biscoe            48.2           14.3              210.0
# 331     Gentoo     Biscoe            49.8           15.9              229.0
# 307     Gentoo     Biscoe            51.3           14.2              218.0
# 125     Adelie  Torgersen            40.6           19.0              199.0
# 327     Gentoo     Biscoe            53.4           15.8              219.0
# 265     Gentoo     Biscoe            43.6           13.9              217.0
# 171  Chinstrap      Dream            49.2           18.2              195.0
# 72      Adelie  Torgersen            39.6           17.2              196.0
# 238     Gentoo     Biscoe            46.2           14.5              209.0
# 264     Gentoo     Biscoe            50.5           15.9              222.0
# 24      Adelie     Biscoe            38.8           17.2              180.0
# 34      Adelie      Dream            36.4           17.0              195.0
# 60      Adelie     Biscoe            35.7           16.9              185.0
# 67      Adelie     Biscoe            41.1           19.1              188.0
# 54      Adelie     Biscoe            34.5           18.1              187.0
# 102     Adelie     Biscoe            37.7           16.0              183.0
# 43      Adelie      Dream            44.1           19.7              196.0
# 288     Gentoo     Biscoe            43.5           14.2              220.0
# 32      Adelie      Dream            39.5           17.8              188.0
# 136     Adelie      Dream            35.6           17.5              191.0
# 277     Gentoo     Biscoe            45.5           15.0              220.0
# 201  Chinstrap      Dream            49.8           17.3              198.0
# 146     Adelie      Dream            39.2           18.6              190.0
# 269     Gentoo     Biscoe            45.2           15.8              215.0
# 163  Chinstrap      Dream            51.7           20.3              194.0
# 197  Chinstrap      Dream            50.8           18.5              201.0
# 227     Gentoo     Biscoe            46.7           15.3              219.0
# 256     Gentoo     Biscoe            42.6           13.7              213.0
# 298     Gentoo     Biscoe            45.2           13.8              215.0
# 38      Adelie      Dream            37.6           19.3              181.0
#
#      body_mass_g     sex height_group
# 236       4150.0  Female         high
# 308       4875.0  Female         high
# 252       5050.0  Female         high
# 202       3325.0  Female         high
# 3            NaN     NaN          NaN
# 185       4100.0    Male         high
# 261       5700.0    Male         high
# 200       3250.0    Male         high
# 49        4150.0    Male         high
# 27        3200.0  Female       middle
# 66        3350.0  Female       middle
# 254       5150.0  Female         high
# 31        3900.0    Male       middle
# 103       4250.0    Male       middle
# 13        3800.0    Male       middle
# 284       4700.0  Female         high
# 303       5350.0    Male         high
# 273       5000.0    Male         high
# 83        4200.0    Male       middle
# 336       4875.0     NaN         high
# 248       4600.0  Female         high
# 331       5950.0    Male         high
# 307       5300.0    Male         high
# 125       4000.0    Male       middle
# 327       5500.0    Male         high
# 265       4900.0  Female         high
# 171       4400.0    Male         high
# 72        3550.0  Female       middle
# 238       4800.0  Female         high
# 264       5550.0    Male         high
# 24        3800.0    Male       middle
# 34        3325.0  Female       middle
# 60        3150.0  Female       middle
# 67        4100.0    Male       middle
# 54        2900.0  Female          low
# 102       3075.0  Female       middle
# 43        4400.0    Male         high
# 288       4700.0  Female         high
# 32        3300.0  Female       middle
# 136       3175.0  Female       middle
# 277       5000.0    Male         high
# 201       3675.0  Female         high
# 146       4250.0    Male       middle
# 269       5300.0    Male         high
# 163       3775.0    Male         high
# 197       4450.0    Male         high
# 227       5200.0    Male         high
# 256       4950.0  Female         high
# 298       4750.0  Female         high
# 38        3300.0  Female       middle

# %% [markdown]
# ***Задача №69.***
# 1. Изобразить гистограмму по flipper_length_mm
# с оттенком height_group. Сделать анализ

# %%
sns.histplot(data=penguins, x='flipper_length_mm', hue='height_group');

# %% [markdown]
# Задача 44: В ячейке ниже представлен код генерирующий DataFrame, которая состоит всего из 1 столбца. Ваша задача перевести его в one hot вид. Сможете ли вы это сделать без get_dummies?
#
#
# - import random
# - lst = ['robot'] * 10
# - lst += ['human'] * 10
# - random.shuffle(lst)
# - data = pd.DataFrame({'whoAmI':lst})
# - data.head()

# %%
import pandas as pd
import numpy as np
import random

# %%
import random
lst = ['robot'] * 10
lst += ['human'] * 10
random.shuffle(lst)
data = pd.DataFrame({'whoAmI':lst})
data.head(5)
# Out:
#   whoAmI
# 0  human
# 1  human
# 2  robot
# 3  robot
# 4  robot

# %%
data['tmp'] = 1
data.set_index([data.index, 'whoAmI'], inplace=True)
data = data.unstack(level=1, fill_value = 0).astype(int)
data.columns = data.columns.droplevel()
data.columns.name = None
print(data)
# Out:
#     human  robot
# 0       1      0
# 1       1      0
# 2       0      1
# 3       0      1
# 4       0      1
# 5       1      0
# 6       1      0
# 7       1      0
# 8       0      1
# 9       0      1
# 10      1      0
# 11      1      0
# 12      0      1
# 13      0      1
# 14      1      0
# 15      0      1
# 16      0      1
# 17      1      0
# 18      0      1
# 19      1      0
